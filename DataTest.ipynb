# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
data = pd.read_csv("drive/Shared drives/Ignition Hacks/Comp Sci/Problem Based/Private Data/judgement_private.csv")
print(data.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#        ID  ... Sentiment
# 0  599303  ...         1
# 1  359673  ...         0
# 2  391095  ...         1
# 3  820049  ...         0
# 4  658429  ...         1
#
# [5 rows x 4 columns]

# %%
data.head()
# Out:
#        ID  ... Sentiment
# 0  599303  ...         1
# 1  359673  ...         0
# 2  391095  ...         1
# 3  820049  ...         0
# 4  658429  ...         1
#
# [5 rows x 4 columns]

# %%
x = data["Sentiment"][0:299999].value_counts()
y = data["Sentiment"][300000:599999].value_counts()
print("Percentage Positive Sentiment in first 300000: {}%".format((x[1]/300000*100).round(2)))
print("Percentage Positive Sentiment in second 300000: {}%".format((y[1]/300000*100).round(2)))
#print("Negative Sentiment: {}".format(x))
#data["Sentiment"][10:20].value_counts()
# Out:
# Percentage Positive Sentiment in first 300000: 49.94%
# Percentage Positive Sentiment in second 300000: 50.06%

# %%
data = data.sample(frac = 1)
